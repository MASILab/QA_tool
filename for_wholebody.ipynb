# %%
import nibabel as nib
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_root = '/nfs/masi/MCL/nifti/npy_eror0506_corr2/34334985177/20091125/34334985177time20091125.nii.gz'

nii = nib.load(data_root)
img = nii.get_data()
img.shape
new_img = img[112: 378, 149: 333, 132: 228]
new_nii = nib.Nifti1Image(new_img, nii.affine)
nib.save(new_nii, '/nfs/masi/MCL/nifti/npy_eror0506_corr2/34334985177/20091125/34334985177time20091125.nii.gz')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-303faad5108f> in <module>
# ----> 1 img_r =img.rotate(30)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'rotate'

# %%
# Out:
# (-0.5, 560.5, 511.5, -0.5)

# %%
# tmp just test
df = pd.read_csv('/nfs/masi/MCL/xnat/xnat20200816_moffti/upload.csv')
session_list = list(set(df['session_label'].tolist()))

# %%
f = open('/nfs/masi/MCL/file/txt/for_download/xnat20200816_moffti.txt', 'w')
for sess in session_list:
    f.write(sess + '\n')
f.close()

# %%
import os
prep_new = os.listdir('/nfs/masi/MCL/DSB_File/tmp_decamp0815/prep')
prep = os.listdir('/nfs/masi/MCL/DSB_File/prep')
print (set(prep_new) & set(prep))
# Out:
# set()
